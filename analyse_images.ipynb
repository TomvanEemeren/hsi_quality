# %%
from data_loader import load_data_from_url

load_data_from_url("libya")
# Out:
# Saved image to datasets/libya/2025-04-25T09-12-15Z.png
# Saved image to datasets/libya/2025-04-27T09-22-39Z.png
# Saved image to datasets/libya/2025-06-01T09-08-40Z.png
# Saved image to datasets/libya/2025-06-05T09-28-15Z.png
# Saved image to datasets/libya/2025-06-06T09-33-06Z.png
# Saved image to datasets/libya/2025-06-20T09-05-47Z.png
# Saved image to datasets/libya/2025-06-21T09-10-36Z.png
# Saved image to datasets/libya/2025-06-22T09-15-25Z.png
# Saved image to datasets/libya/2025-06-23T09-20-11Z.png
# Saved image to datasets/libya/2025-06-24T09-24-59Z.png
# Saved image to datasets/libya/2025-07-12T09-15-20Z.png
# Saved image to datasets/libya/2025-09-12T09-10-46Z.png
# Saved image to datasets/libya/2025-11-02T09-26-22Z.png
# Saved metadata to datasets/libya/metadata.csv.

# %%
import pandas as pd

dataset = "dubai"
metadata = pd.read_csv(f"datasets/{dataset}/metadata.csv")
metadata.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 49 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   location_description             24 non-null     str
#  1   timestamp_acquired               24 non-null     float64
#  2   timestamp_acquired_string        24 non-null     str
#  3   timestamp_processed              24 non-null     float64
#  4   target_latitude                  21 non-null     float64
#  5   target_longitude                 21 non-null     float64
#  6   framerate                        24 non-null     float64
#  7   exposure                         24 non-null     float64
#  8   lines                            24 non-null     int64
#  9   samples                          24 non-null     int64
#  10  bands                            24 non-null     int64
#  11  bands_raw                        24 non-null     int64
# ...

# %%
metadata_filtered = metadata[["timestamp_acquired_string", "hypso", "target_latitude", "target_longitude", "latitude", "longitude", "star_tracker_blinded_percentage", "elevation", "off_nadir", "solar_zenith_angle", "sat_zenith_angle", "area"]]
metadata_filtered
# Out:
#    timestamp_acquired_string  hypso  target_latitude  target_longitude  \
# 0   2025-03-16 07:06:35+0000      2            25.11             55.18
# 1   2025-04-02 07:07:41+0000      2              NaN               NaN
# 2   2025-04-03 07:13:14+0000      2            25.11             55.18
# 3   2025-04-20 07:09:41+0000      2            25.11             55.18
# 4   2025-05-07 07:02:28+0000      2              NaN               NaN
# 5   2025-05-27 07:07:40+0000      2              NaN               NaN
# 6   2025-06-14 07:00:33+0000      2            25.11             55.18
# 7   2025-06-17 07:15:02+0000      2            25.11             55.18
# 8   2025-07-24 07:00:03+0000      2            25.11             55.18
# 9   2025-07-26 07:09:22+0000      2            25.11             55.18
# 10  2025-08-15 07:05:45+0000      2            25.11             55.18
# 11  2025-09-26 06:58:59+0000      2            25.11             55.18
# ...
